# %% [markdown]
# # Extraction of Wiki data

# %% [markdown]
# ## Importing the necessary packages

# %%
import pandas as pd
import json
import requests
from SPARQLWrapper import SPARQLWrapper, JSON

# %% [markdown]
# ## Defining queries for fetching wiki data

# %% [markdown]
# The **get_wikidata_id()** function takes a name as input and returns the Wikidata ID for that name. If the entity is not found, the function returns None.
#
# The function first constructs a URL to the Wikidata API. The API endpoint wbsearchentities takes a number of parameters, including the name of the entity, the language, and the format of the response. The function then uses the requests library to make a GET request to the API. The response is a JSON object, which the function parses.
#
# The function then checks if the JSON object contains any entities. If it does, the function returns the ID of the first entity. Otherwise, the function returns None.

# %%
def get_wikidata_id(name):
    """
    Get the Wikidata ID for a given name.

    Args:
        name (str): The name of the entity.

    Returns:
        str: The Wikidata ID, or None if the entity is not found.
    """

    url = 'https://www.wikidata.org/w/api.php'
    params = {
        'action': 'wbsearchentities',
        'format': 'json',
        'language': 'en',
        'search': name
    }
    response = requests.get(url, params=params)
    data = response.json()

    # Check if the entity was found.

    if len(data['search']) > 0:
        return data['search'][0]['id']
    else:
        return None

# %%
def extract_value(json_string):
  """Extracts the value component from a JSON string.

  Args:
    json_string: A JSON string.

  Returns:
    The value component of the JSON string.
  """

  json_object = json.loads(json.dumps(json_string))
  if not isinstance(json_object, float):
    return json_object["value"]
  else:
    return json_object

# %%
def get_knowledge_graph(wikidata_id):
    """
    Get the knowledge graph for a given Wikidata ID.

    Args:
        wikidata_id (str): The Wikidata ID of the entity.

    Returns:
        dict: The knowledge graph, a dictionary of properties to values.
    """

    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    query = """
SELECT    ?companyLabel ?ticker ?countryLabel ?headquartersLabel ?ceoLabel ?industryLabel ?businessLabel ?productLabel ?competitorLabel ?nicknameLabel ?subsidiaryLabel WHERE {
      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
      # ?company wdt:P361 wd:%s.
      OPTIONAL {
        # ?company p:P414 ?exchange .
        # ?exchange ps:P414 wd:Q13677 .
        # ?exchange pq:P249 ?ticker .
      }
      OPTIONAL { ?company wdt:P17 ?country. }
      OPTIONAL { ?company wdt:P159 ?headquarters. }
      OPTIONAL { ?company wdt:P169 ?ceo. }
      OPTIONAL { ?company wdt:P452 ?industry. }
      OPTIONAL { ?company wdt:P199 ?business. }
      OPTIONAL { ?company wdt:P1056 ?product. }
#       OPTIONAL { ?company wdt:P169 ?competitor. }
      OPTIONAL { ?company wdt:P1449 ?nickname. }
      OPTIONAL { ?company wdt:P355 ?subsidiary. }
    }
    """ % (wikidata_id)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()

    df = pd.DataFrame(results["results"]["bindings"])
    df.rename(columns={"propertyLabel": "Property", "value": "Value"}, inplace=True)

    # Extract the value from the string
    df = df.applymap(extract_value)

    return df

# %% [markdown]
# ## Extracting wiki data id for Dow Jones

# %%
wikidata_id = get_wikidata_id('Dow Jones Industrial Average')

# %% [markdown]
# ## Extracting data of Companies listed in Dow Jones Index

# %%
knowledge_graph = get_knowledge_graph(wikidata_id)

# %%
#companyLabel_tuples = knowledge_graph["companyLabel"].apply(tuple)
# 21334                                     retail
# 21610                          industrial sector
# 21747                         financial services
# 21751                         financial services
# 21754                    pharmaceutical industry
# 21834                    pharmaceutical industry
# 21955                                     retail
# 21957                                  insurance
# 21958                            holding company
# 21962                                health care
# 21964                              food industry
# 22656                          chemical industry
# 22688                         petroleum industry
# 22698                         financial services
# 23168                              arms industry
#
#                                 businessLabel             productLabel  \
# 0                                 Apple Store                     iPod
# 100                                       NaN        computer hardware
# 300                                       NaN      networking hardware
# 4464                       Microsoft Research  Microsoft Visual Studio
# 7164              Boeing Commercial Airplanes               Boeing 747
# 7564                      IBM Global Services          cloud computing
# 7906                                      NaN           liquid crystal
# 11864                                  McCafé                McChicken
# 14207                       GE Transportation          aircraft engine
# 18045  Disney Parks, Experiences and Products                 software
# 20937                                     NaN                 gasoline
# 21063                                     NaN                 software
# 21087                                     NaN                insurance
# 21245                                     NaN           medical device
# 21308                                     NaN                      NaN
# 21329                                     NaN                      NaN
# 21334                                     NaN              supermarket
# 21610                                     NaN                 clothing
# 21747                                     NaN          investment bank
# 21751                                     NaN                      NaN
# 21754                                     NaN               sildenafil
# 21834                                     NaN                      NaN
# 21955                                     NaN           home appliance
# 21957                                     NaN       insurance contract
# 21958                                     NaN                      NaN
# 21962                                     NaN                      NaN
# 21964                                     NaN       alcoholic beverage
# 22656                                     NaN  polytetrafluoroethylene
# 22688                                     NaN                petroleum
# 22698                                     NaN              credit card
# 23168                                     NaN                      NaN
#
#                                          subsidiaryLabel nicknameLabel ticker
# 0                                            Apple Store           NaN    NaN
# 100                                          McAfee, LLC     Chipzilla    NaN
# 300                                       Webex by Cisco           NaN    NaN
# 4464                                       ZeniMax Media           NaN    NaN
# 7164                         Boeing Commercial Airplanes           NaN     BA
# 7564                                             Red Hat           NaN    IBM
# 7906                                  Seven Seas Limited           NaN    NaN
# 11864                                  McDonald's Canada         Mekáč    MCD
# 14207                                                NBC           NaN     GE
# 18045                                              Pixar           NaN    DIS
# 20937                                       Imperial Oil           NaN    XOM
# 21063                           3M Innovative Properties           NaN    MMM
# 21087                                         Chase Bank           NaN    JPM
# 21245  Johnson & Johnson Pharmaceutical Research and ...           NaN    JNJ
# 21308                                    Perkins Engines           NaN    CAT
# 21329                                                AOL           NaN     VZ
# 21334                                               Asda           NaN    WMT
# 21610                                           Converse           NaN    NKE
# 21747                                                NaN           NaN     GS
# 21751                                                NaN           NaN    AXP
# 21754                             G. D. Searle & Company           NaN    PFE
# 21834                                           Gillette           NaN     PG
# 21955                                                NaN           NaN     HD
# 21957                                                NaN           NaN    TRV
# 21958                                    Pratt & Whitney           NaN    UTX
# 21962                                                NaN           NaN    UNH
# 21964                                       Costa Coffee           NaN     KO
# 22656                                            Danisco           NaN     DD
# 22688                                             Texaco           NaN    CVX
# 22698                                        Visa Europe           NaN      V
# 23168                                    Pratt & Whitney           NaN    RTX
